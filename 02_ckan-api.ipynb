# %% [markdown]
# # CCCA Data Centre CKAN API
# ## Workshop Notebook 2

# %% [markdown]
# ### Original notebook from:
#
# Georg Seyerl (georg.seyerl@ccca.ac.at)
#
# ### Further Information:
#
# [**CKAN API Reference**](http://docs.ckan.org/en/ckan-2.7.3/api/index.html#action-api-reference)
#
# [**ckanapi Python Modul**](https://github.com/ckan/ckanapi)

# %% [markdown]
# ================

# %% [markdown]
# ## Connect to the CCCA Data Server

# %% [markdown]
# Import necessary libraries

# %%
from ckanapi import RemoteCKAN
from pprint import pprint #Pretty Print - Print dictionaries in a nice manner

# %% [markdown]
# Connect to the Server - important: Use your own apikey (http://data.ccca.ac.at/user)

# %%
data_ccca = RemoteCKAN('https://data.ccca.ac.at', apikey='54cc28ea-5391-4e87-8ebf-d1b231e5b52b')

# %% [markdown]
# ## Packages

# %% [markdown]
# List packages (datasets), but only latest versions

# %%
ls_pkg_latest = data_ccca.call_action('package_list', {})

# %%
pprint(ls_pkg_latest[:10])
# Out:
# ['oks15_climate_change_signal_of_temperature_indices_cw-sum-days-rcp85-farfuture-jja',
#  'oks15_climate_change_signal_of_temperature_indices_tm-rcp85-nearfuture-son',
#  'oks15_precipitation_climate_indices_sdii_1961_2010_annual',
#  'oks15_climate_change_signal_of_precipiation_indices_rx5day-rcp85-farfuture-jja',
#  'oks15_30y-mean_global_radiation_indices_rsds_1981_2010_annual_meanrsds_1981_2010_annual_mean',
#  'oks15_climate_change_signal_of_temperature_indices_cw-sum-days-rcp85-farfuture-annual',
#  'beratungsbericht-factsheet-land-salzburg',
#  'oks15_temperature_climate_indices_hdd_october_april_1961_2011_annual',
#  'oks15_climate_change_signal_of_precipiation_indices_rr1-moderate-rcp85-farfuture-annual',
#  'oks15_climate_change_signal_of_temperature_indices_id7-rcp45-nearfuture-djf']

# %% [markdown]
# List packages, including all versions

# %%
ls_pkg_all = data_ccca.call_action('package_list', {'include_versions':True})

# %%
pprint(ls_pkg_all[:10])
# Out:
# ['3pclim-data-complete-v01',
#  '3pclim_entwicklung_temperatur_niederschlag_jahresreihen-v01',
#  '3pclim_entwicklung_temperatur_niederschlag_monatsreihen-v01',
#  '3pclim_entwicklung_temperatur_niederschlag_saisonale_reihen-v01',
#  '3pclim_entwicklung_temperatur_niederschlag-v01',
#  '3pclim_gletscher-v01',
#  '3pclim_konvektion_dauer_distanz-v01',
#  '3pclim_konvektion_entstehung_zerfall-v01',
#  '3pclim_konvektion_gewittertage-v01',
#  '3pclim_konvektion_nr_zellen_pro_monat-v01']

# %% [markdown]
# Metadata for one package (first in list)

# %%
d_pkg = data_ccca.call_action('package_show', {'id': ls_pkg_latest[0]})

# %%
pprint(d_pkg.keys())
# Out:
# [u'owner_org',
#  u'maintainer',
#  u'groups',
#  u'issued',
#  u'use_limitation',
#  u'private',
#  u'maintainer_email',
#  u'num_tags',
#  u'specifics',
#  u'frequency',
#  u'id',
#  u'metadata_created',
#  u'citation_info',
#  u'temporal_end',
#  u'dimensions',
#  u'metadata_modified',
#  u'author',
#  u'author_email',
#  u'controlled_tags',
#  u'specification',
#  u'provenance',
#  u'state',
#  u'relations',
#  u'equiv_scale',
#  u'version',
#  u'spatial',
#  u'creator_user_id',
#  u'uri',
#  u'conformance',
#  u'variables',
#  u'resources',
#  u'num_resources',
#  u'author_department',
#  u'title',
#  u'resource_status',
#  u'language',
#  u'spatial_name',
#  u'license_id',
#  u'temporal_start',
#  u'tags',
#  u'scale_dist',
#  u'name',
#  u'isopen',
#  u'created',
#  u'url',
#  u'type',
#  u'notes',
#  u'license_title',
#  u'modified',
#  u'license_url',
#  u'organization',
#  u'revision_id',
#  u'maintainer_department']

# %%
d_pkg
# Out:
# {u'author': u'Michael Hofstaetter',
#  u'author_department': u'',
#  u'author_email': u'michael.hofstaetter@zamg.ac.at',
#  u'citation_info': u'',
#  u'conformance': u'',
#  u'controlled_tags': u'[]',
#  u'created': u'2016-09-02T12:52:00',
#  u'creator_user_id': u'4b957eb9-cd7f-4b47-a1b8-63b8919cffd8',
#  u'dimensions': [],
#  u'equiv_scale': u'1',
#  u'frequency': u'ANNUAL',
#  u'groups': [{u'description': u'',
#    u'display_name': u'Climate Indices',
#    u'id': u'acf9d779-49d7-43ec-8745-c1cd8ee60064',
#    u'image_display_url': u'https://data.ccca.ac.at/images/ci_group.png',
#    u'name': u'ci',
#    u'title': u'Climate Indices'},
#   {u'description': u'Processes and phenomena of the atmosphere.',
#    u'display_name': u'Climatology',
#    u'id': u'b928139c-3995-4ecd-ad3f-097ce133c0f2',
#    u'image_display_url': u'https://data.ccca.ac.at/images/climate.png',
#    u'name': u'meteorology',
#    u'title': u'Climatology'},
#   {u'description': u'',
#    u'display_name': u'Observed Data',
#    u'id': u'cab22c2a-b0e5-49b4-8cb8-68f0977e76c6',
#    u'image_display_url': u'https://data.ccca.ac.at/images/grp_obs.png',
#    u'name': u'observed_data',
#    u'title': u'Observed Data'},
#   {u'description': u'',
#    u'display_name': u'Precipitation',
#    u'id': u'abe252ca-fcdc-4b2f-a994-22a8549c55a2',
#    u'image_display_url': u'https://data.ccca.ac.at/images/rain_group.png',
#    u'name': u'precipitation',
#    u'title': u'Precipitation'},
#   {u'description': u'## Climate Scenarios for Austria (1971 - 2100)\r\n\r\nDepending on the climate parameters, time of year, scale and degree of adaptation, the advancing global climate change has led to changes that impact systems in different ways. Climate change adaptation and the identification of possible intervention measures requires a founded analysis of the risks related to climate change and its impacts. In order to adequately prepare for impending changes, the Austrian Federal Ministry of Agriculture, Forestry, Environment and Water Management, in partnership with the nine Austrian States (L\xe4nder), has initiated the project \xd6KS15, which aims at preparing a basis for developing action strategies for climate change adaptation.\r\n\r\nThe Central Institute for Meteorology and Geodynamics (ZAMG), the Wegener Center for Climate and Global Change at the University of Graz, and the Interfaculty Department of Geoinformatics \u2013 Z_GIS at the University of Salzburg have been commissioned to undertake an analysis of past and future climate change in the Austrian States.\r\n\r\nAs a result, a set of regional climate projections, employing a climate-protection-scenario (RCP4.5) and a business-as-usual-scenario (RCP8.5) and covering the period 1971 to 2100, from the EURO-CORDEX (www.euro-cordex.net) initiative has been specifically prepared (interpolated and bias-corrected) for the Austrian territory. This set can be downloaded here (https://data.ccca.ac.at/group/oks15).\r\n\r\nFurther results (derived climate change signals, their position within the range of the EURO-CORDEX climate models as well as an assessment of these), primarily prepared for decision makers in policy and practitioners, that have been fed into the federal and state GIS systems and will be now integrated into the CCCA \xd6KS15 data portal as well.',
#    u'display_name': u'\xd6KS15',
#    u'id': u'625ea88f-bd3c-417a-8b57-dfaa8b55b56b',
#    u'image_display_url': u'https://data.ccca.ac.at/uploads/group/2016-11-10-143542.090074okslogo.png',
#    u'name': u'oks15',
#    u'title': u'\xd6KS15'}],
#  u'id': u'dd7d2d6b-0dff-424d-9337-9f2b52f7c4f7',
#  u'isopen': True,
#  u'issued': u'2016-09-02T12:52:00',
#  u'language': u'eng',
#  u'license_id': u'cc-by-sa',
#  u'license_title': u'Creative Commons Attribution Share-Alike',
#  u'license_url': u'http://www.opendefinition.org/licenses/cc-by-sa',
#  u'maintainer': u'Annemarie Lexer',
#  u'maintainer_department': u'',
#  u'maintainer_email': u'annemarie.lexer@zamg.ac.at',
#  u'metadata_created': u'2018-03-09T12:41:10.683165',
#  u'metadata_modified': u'2018-03-14T11:03:34.261837',
#  u'modified': u'2016-09-05T13:22:40.012796',
#  u'name': u'oks15_precipitation_climate_indices_sdii_1961_2010_annual-v01',
#  u'notes': u'annual simple daily precipitation intensity',
#  u'num_resources': 1,
#  u'num_tags': 1,
#  u'organization': {u'approval_status': u'approved',
#   u'created': u'2016-05-02T14:30:56.861679',
#   u'description': u'Zentralanstalt f\xfcr Meteorologie und Geodynamik\r\nHohe Warte 38\r\n1190 Wien',
#   u'id': u'08ba468c-3c79-40a6-a131-b31e07758938',
#   u'image_url': u'2016-05-02-123056.833229ZAMGlogoB.svg.png',
#   u'is_organization': True,
#   u'name': u'zamg',
#   u'revision_id': u'45c55134-735a-4a20-a4d3-0166c0273648',
#   u'state': u'active',
#   u'title': u'ZAMG',
#   u'type': u'organization'},
#  u'owner_org': u'08ba468c-3c79-40a6-a131-b31e07758938',
#  u'private': False,
#  u'provenance': u'Klimaindizes f\xfcr Niederschlag von 1961 bis 2010. Daily precipitation amount interpolated to 1km equidistant grid using 718 station data.',
#  u'relations': [],
#  u'resource_status': u'001',
#  u'resources': [{u'access_rights': u'copyright',
#    u'cache_last_updated': None,
#    u'cache_url': None,
#    u'created': u'2016-09-05T15:22:40.100183',
#    u'datastore_active': False,
#    u'description': u'annual simple daily precipitation intensity',
#    u'format': u'NetCDF',
#    u'hash': u'b48988c2a5097b220339d4c429a7e07b',
#    u'id': u'ff9aa026-4e34-4b6f-a81e-af0db1f6c2a8',
#    u'last_modified': u'2016-09-05T13:22:40.012796',
#    u'mimetype': None,
#    u'mimetype_inner': None,
#    u'name': u'annual simple daily precipitation intensity',
#    u'package_id': u'dd7d2d6b-0dff-424d-9337-9f2b52f7c4f7',
#    u'position': 0,
#                  'Trust-values:\n'
#                  ' 0.0 - significant changes but no model agreement\n'
#                  ' 0.5 - no significant change\n'
#                  ' 1.0 - significant changes and high model agreement\n',
#   'format': 'NetCDF',
#   'hash': '3d3fd3b5ae5d55fe6fa55be4dc087400',
#   'id': '18646b00-91ff-40bf-8d9b-2f5c2dd576f4',
#   'last_modified': '2016-12-29T13:44:22.642528',
#   'mimetype': None,
#   'mimetype_inner': None,
#   'name': 'Climate change signal of cold wave',
#   'package_id': '4609c014-1a65-49a1-b440-f1336613baf4',
#   'position': 0,
#   'resource_type': None,
#   'revision_id': '11cf357c-eda8-4559-b1f4-fa23d62215bb',
#   'size': '3133272',
#   'state': 'active',
#   'url': 'https://data.ccca.ac.at/dataset/4609c014-1a65-49a1-b440-f1336613baf4/resource/18646b00-91ff-40bf-8d9b-2f5c2dd576f4/download/cw-sum-daysrcp85abs-ccs2071-2100--1971-2000jja.nc',
#   'url_type': 'upload',
#   'webstore_last_updated': None,
#   'webstore_url': None}]

# %% [markdown]
# ## Search for packages/dataset
# [**package_search API Reference**](http://docs.ckan.org/en/ckan-2.7.3/api/index.html#ckan.logic.action.get.package_search)
#
# [**CCCA Data Centre search**](https://data.ccca.ac.at/dataset?groups=bias-corrected&extras_specifics_Variables=Precipitation+%28rr%29&groups=rcp85)

# %% [markdown]
# Search for datasets with specific search parameters.

# %%
ls_pkg_search = data_ccca.call_action(
    'package_search', 
    {'fq':"groups:bias-corrected AND extras_specifics_Variables:Precipitation?\(rr\) AND groups:rcp85"} )

# %%
pprint(ls_pkg_search.keys())
# Out:
# dict_keys(['count', 'sort', 'facets', 'results', 'search_facets'])

# %% [markdown]
# Extract metadata (url) from resources in datasets where the lowercased name contains the string "dap"

# %%
[[res['url'] for res in pkg['resources'] if "dap" in res['name'].lower()][0]
    for pkg in ls_pkg_search['results']
]
# Out:
# ['https://data.ccca.ac.at/thredds/dodsC/ckan/b18/992/94-9d3a-4c5c-8afb-259120d9b0b2',
#  'https://data.ccca.ac.at/thredds/dodsC/ckan/103/c6f/4d-2ec9-4e79-9555-63d52314a247',
#  'https://data.ccca.ac.at/thredds/dodsC/ckan/089/a87/b5-8164-47db-922a-0a784c727c72',
#  'https://data.ccca.ac.at/thredds/dodsC/ckan/780/f06/64-209f-442e-a38f-acf073e0c5e9',
#  'https://data.ccca.ac.at/thredds/dodsC/ckan/811/312/f5-2006-471e-8220-53a75876ecdd',
#  'https://data.ccca.ac.at/thredds/dodsC/ckan/1c3/081/4d-4f13-4464-8a99-f032fd7383e7',
#  'https://data.ccca.ac.at/thredds/dodsC/ckan/91c/c78/41-51be-4386-af21-6e75c4bb5b39',
#  'https://data.ccca.ac.at/thredds/dodsC/ckan/264/178/50-6d6e-40af-b682-3d3495a83bcb',
#  'https://data.ccca.ac.at/thredds/dodsC/ckan/6d7/713/d4-7fb5-41de-97b5-e24ca4cbc4fe',
#  'https://data.ccca.ac.at/thredds/dodsC/ckan/f67/48f/11-f7b0-476b-b084-e2f789544815']
